# %%
print("Hello vatsal")
# Out:
# Hello vatsal

# %%
x=5
print(x)

x=x+5
print(x)

x=x*2
print(x)
# Out:
# 5
# 10
# 20

# %%
a= 17
b =3

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# 20
# 14
# 51
# 5.666666666666667
# 5
# 2

# %%
name=" hello i'm vatsal!"
print(name[::-1])
# Out:
# !lastav m'i olleh

# %%
name="Vatsal"
my_age=22

print(f"Hello i'm {name} and i am {my_age} years old.")
# Out:
# Hello i'm Vatsal and i am 22 years old.

# %%
text = "Machine Learning"

print(text[:7])
print(text[7:])
print(text[::3])
# Out:
# Machine
# Learning
# Mheai

# %%
print(bool({}))
print(bool({"AI": 1}))
print(bool(()))
print(bool((0,)))
# Out:
# False
# True
# False
# True

# %%
name= input("Enter Your Name:")
age= int(input("Enter your age:"))

print(f"Hello {name}!")
print(f"Next year you will be {age + 1} years old.")
# Out:
# Hello VK!
# Next year you will be 23 years old.
