# %% [markdown]
# # DAY-4 Python Data Types & Variables
#
# ### Learn about numbers, strings, lists, tuples, dictionaries, sets, etc. & Dynamic typing, Naming conventions,Multiple assignment, Type checking (type())
