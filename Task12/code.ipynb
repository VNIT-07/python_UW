# %%
print(__name__)
# Out:
# __main__

# %%
def add(a,b):
    return a + b

if __name__ == "__main__":
    print("Running directly this code.")
    print(add(2,3))
# Out:
# Running directly this code.
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 9
#       5 if __name__ == "__main__":
#       6     print("Running directly this code.")
#       7     print(add(2,3))
#       8
# ----> 9 math.add(2,3)
#
# AttributeError: module 'math' has no attribute 'add'
