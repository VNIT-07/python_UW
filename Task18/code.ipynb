# %%
class student:
    
    s1 = student()
    s1.name = "Vinit"
    s1.age = 21

    print(s1.name)     
    print(s1.age)

# %%
class company:
    def __init__(self):
        print("v")
s1 = company()

# %%
class Student:

    def __init__(self):
        print("A Student object is created")
c = Student()

# %%
class stud:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        print(self.name)
        print(self.age)
s1 = stud("vinit",21)
s2 = stud("Vatsal", 22)
s3 = stud("Mayur", 21)

# %%
class Student:

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def introduce(self):
        print(f"My name is {self.name}")
        print(f"My age is {self.age}")
s1 = Student("Vinit",21)
s2 = Student("Harsh",22)
print(s2.__dict__)
# s.introduce()

# %%
class Student:
    school = "ABC School"  # Class variable

    def __init__(self, name):
        self.name = name

s1 = Student("Alice")
s2 = Student("Bob")

print(s1.name ,s1.school)  # ABC School
print(s2.name)  # ABC School

# %%
class BankAccount:

    def __init__(self):
        self.__balance = 1000

    def get_balance(self):
        return self.__balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount

# %%
class Student:

    def __init__(self, name):
        self.name = name
        self.__marks = 0      # Private variable

    # Setter
    def set_marks(self, marks):
        if 0 <= marks <= 100:
            self.__marks = marks
            print("Marks updated successfully!")
        else:
            print("Invalid marks! Marks should be between 0 and 100.")

    # Getter
    def get_marks(self):
        return self.__marks

    # Inform the result
    def show_result(self):
        print(f"\nStudent Name : {self.name}")
        print(f"Marks        : {self.__marks}")

        if self.__marks >= 90:
            print("Grade        : A+")
        elif self.__marks >= 75:
            print("Grade        : A")
        elif self.__marks >= 60:
            print("Grade        : B")
        elif self.__marks >= 40:
            print("Grade        : C")
        else:
            print("Grade        : Fail")


# ---------------- Main Program ----------------

name = input("Enter student name: ")
student = Student(name)

marks = int(input("Enter marks (0-100): "))
student.set_marks(marks)

student.show_result()

# %% [markdown]
# ## CLASS AND INSTANCE VARIABLE

# %%
class student:
    school = "SD JAIN" # Class Variable
student.school
# Out:
# 'SD JAIN'

# %%
class student:
    
    def __init__(self, marks):
        self.marks = marks # Instance Variable
        
m1=student(100)
m1.marks
# Out:
# 100

# %% [markdown]
# ## INHERITANCE

# %%
class human():
    def eat(self):
        print("eating...")

class dog(human):
    def barking(self):
        print("Barking...")
        
Dog = dog()
Dog.eat()
# Out:
# eating...

# %%
class parent:
    def knows_english(self, name):
        print(f"My parent {name} knows english, i am a child class")
    
class child(parent):
    def knows_coding(self):
        print('''I knows how to write code: print("Hello world")''')
c1 = child()
c1.knows_english("vinit")
c1.knows_coding()
# Out:
# My parent vinit knows english, i am a child class
# I knows how to write code: print("Hello world")

# %%
class person:
    def __init__(self, name):
        self.name = name
        
class student(person):
    def __init__(self, roll_no, name, age):
        super().__init__(name)
        self.rollno = roll_no
        self.age = age

p = student(209,"Vinit", 21)
print(p.rollno, p.name, p.age)
# Out:
# 209 Vinit 21

# %%
# Create a Vehicle class with a constructor that accepts brand. Create a Car class that inherits from it, adds model, and displays both values.

class vehicle:
    def __init__(self, brand):
        self.brand = brand

class car(vehicle):
    def __init__(self, brand, models):
        super().__init__(brand)
        self.model = models
        

c = car("BMW", "BMW M5")

print(c.brand)
print(c.model)
# Out:
# BMW
# BMW M5

# %%
class person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    def introduce(self):
        print(f"Hello my name is {self.name} and my age is {self.age}")

class employee(person):
        def __init__(self, emp_id, name, age):
            super().__init__(name, age)
            self.emp_id = emp_id
            
        def work(self):
            print("Working...")

class manager(employee):
    def __init__(self, dept, emp_id, name, age):
            super().__init__(emp_id,name,age)
            self.dept = dept
            
    def manage_team(self):
        print(f"Managing the {self.dept} team.")
        
class developer(employee):
    def __init__(self, programming_lang, emp_id, name, age):
            super().__init__(emp_id, name, age)
            self.pl = programming_lang
            
    def write_code(self):
        print(f"Writing code in {self.pl}.")

man = manager("HR", 101, "Harsh", 22)
dev = developer("Python", 102, "Vatsal", 22)

print("Manager:")
man.introduce()
man.work()
man.manage_team()

print("\nDeveloper:")
dev.introduce()
dev.work()
dev.write_code()
# Out:
# Manager:
# Hello my name is Harsh and my age is 22
# Working...
# Managing the HR team.
#
# Developer:
# Hello my name is Vatsal and my age is 22
# Working...
# Writing code in Python.

# %% [markdown]
# ## ENCAPSULATION

# %%
# Beginner

class Student:
    name = "Hello"
    _rollNo = 33
    __marks = 20

print(Student.name)
print(Student._rollNo)
print(Student._Student__marks)
# Out:
# Hello
# 33
# 20

# %%
class BankAccount:

    def __init__(self):
        self.__balance = 0

    def deposit(self):
        amount = int(input("Enter the amount to deposit: "))

        if amount > 0:
            self.__balance += amount
            print(f"₹{amount} deposited successfully!")
        else:
            print("Please enter a valid amount.")

    def show_balance(self):
        print(f"Current Balance: ₹{self.__balance}")


bank = BankAccount()

while True:
    print("\n===== BANK MENU =====")
    print("1. Deposit")
    print("2. Show Balance")
    print("3. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        bank.deposit()

    elif choice == "2":
        bank.show_balance()

    elif choice == "3":
        print("Thank you for using our bank!")
        break

    else:
        print("Invalid choice. Please try again.")
# Out:
# ===== BANK MENU =====
# 1. Deposit
# 2. Show Balance
# 3. Exit
# ₹100 deposited successfully!
#
# ===== BANK MENU =====
# 1. Deposit
# 2. Show Balance
# 3. Exit
# ₹200 deposited successfully!
#
# ===== BANK MENU =====
# 1. Deposit
# 2. Show Balance
# 3. Exit
# Thank you for using our bank!

# %%
class dog:
    def sound(self):
        print("Dog says Bark")
    
class cat:
    def sound(self):
        print("Cat says Meow")
        
def make_sound(ani):
    ani.sound()
    
make_sound(dog())
make_sound(cat())
# Out:
# Dog says Bark
# Cat says Meow

# %%
class car:
    def start(self):
        print("Car starts")
    
class bike:
    def start(self):
        print("Bike starts")

def starts(spark):
    spark.start()

starts(car())
starts(bike())
# Out:
# Car starts
# Bike starts

# %%
import gc

gc.enable()
gc.collect()
gc.get_stats()
# Out:
# [{'collections': 198, 'collected': 1666, 'uncollectable': 0},
#  {'collections': 18, 'collected': 366, 'uncollectable': 0},
#  {'collections': 70, 'collected': 45, 'uncollectable': 0}]
